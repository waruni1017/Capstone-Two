# %% [markdown]
# In this notebook, United States trending YouTube video Statistics are studied. The data contains 40949 YouTube video details and 16 features. One video will appear more than once in this dataset, since it is possible that a video stays in the trending list for many days.

# %% [markdown]
# # 1. Import packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime 
import json
import seaborn
from wordcloud import WordCloud, STOPWORDS
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# # 2. Load the data

# %%
YouTube = pd.read_csv("./YOUTUBE DATA/USvideos.csv")

# %% [markdown]
# # 3. Explore the data

# %%
YouTube.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
#                                                 tags    views   likes  \
# 0                                    SHANtell martin   748374   57527
# 1  last week tonight trump presidency|"last week ...  2418783   97185
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...  3191434  146033
# 3  rhett and link|"gmm"|"good mythical morning"|"...   343168   10172
# 4  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...  2095731  132235
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0      2966          15954  https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg
# 1      6146          12703  https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg
# 2      5339           8181  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3       666           2146  https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg
# 4      1989          17518  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False
#
#                                          description
# 0  SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1  One year after the presidential election, John...
# 2  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3  Today we find out if Link is a Nickelback amat...
# 4  I know it's been a while since we did this sho...

# %%
YouTube.shape
# Out:
# (40949, 16)

# %%
YouTube.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40949 entries, 0 to 40948
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                40949 non-null  object
#  1   trending_date           40949 non-null  object
#  2   title                   40949 non-null  object
#  3   channel_title           40949 non-null  object
#  4   category_id             40949 non-null  int64
#  5   publish_time            40949 non-null  object
#  6   tags                    40949 non-null  object
#  7   views                   40949 non-null  int64
#  8   likes                   40949 non-null  int64
#  9   dislikes                40949 non-null  int64
#  10  comment_count           40949 non-null  int64
#  11  thumbnail_link          40949 non-null  object
#  12  comments_disabled       40949 non-null  bool
#  13  ratings_disabled        40949 non-null  bool
#  14  video_error_or_removed  40949 non-null  bool
#  15  description             40379 non-null  object
# dtypes: bool(3), int64(5), object(8)
# memory usage: 4.2+ MB

# %% [markdown]
# We can see that trending_date and publish_time are datetime objects. We will have to fix this at some point. Also, there are 40949 data but in the description column 40379. Looks like we have some data missing. We will have to work on that as well.

# %%
#Summary of numerical variables
YouTube.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  40949.000000  4.094900e+04  4.094900e+04  4.094900e+04   4.094900e+04
# mean      19.972429  2.360785e+06  7.426670e+04  3.711401e+03   8.446804e+03
# std        7.568327  7.394114e+06  2.288853e+05  2.902971e+04   3.743049e+04
# min        1.000000  5.490000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       17.000000  2.423290e+05  5.424000e+03  2.020000e+02   6.140000e+02
# 50%       24.000000  6.818610e+05  1.809100e+04  6.310000e+02   1.856000e+03
# 75%       25.000000  1.823157e+06  5.541700e+04  1.938000e+03   5.755000e+03
# max       43.000000  2.252119e+08  5.613827e+06  1.674420e+06   1.361580e+06

# %% [markdown]
# It can be observed that videos have been in the trending list even though it has zero likes. Number of comments being zero is possible since some videos have disabled commenting.

# %%
#Summeary of categorical variables
YouTube.describe(include=['O'])
# Out:
#            video_id trending_date                                       title  \
# count         40949         40949                                       40949
# unique         6351           205                                        6455
# top     j4KvrAUjn6c      17.16.11  WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# freq             30           200                                          30
#
#        channel_title              publish_time    tags  \
# count          40949                     40949   40949
# unique          2207                      6269    6055
# top             ESPN  2018-05-18T14:00:04.000Z  [none]
# freq             203                        50    1535
#
#                                         thumbnail_link  \
# count                                            40949
# unique                                            6352
# top     https://i.ytimg.com/vi/j4KvrAUjn6c/default.jpg
# freq                                                30
#
#                                               description
# count                                               40379
# unique                                               6901
# top     ► Listen LIVE: http://power1051fm.com/\n► Face...
# freq                                                   58

# %% [markdown]
# There 40949 videos, but only 6351 of them are unique. This makes sense because a video could be trending for more than one day. Most appeared channel is ESPN while the most appeared video title is 'WE MADE OUR MOM CRY...HER DREAM CAME TRUE'.
#
# There are 205 unique dates in this dataset.

# %% [markdown]
# # 4. Clean the data

# %%
YouTube.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %% [markdown]
# ### 4.1 Remove irrelevant features

# %%
del_col =['thumbnail_link', 'description']
df = YouTube.drop(del_col, axis=1)
df.shape
# Out:
# (40949, 14)

# %% [markdown]
# ### 4.2 Check for duplicates

# %%
#check for duplicates
df.duplicated().value_counts()
# Out:
# False    40901
# True        48
# dtype: int64

# %% [markdown]
# We have 48 duplicated rows. Best way to handle this is to get rid of those rows. since it is just 48 out of 40949, it would not effect much.

# %%
df[df.duplicated()]
# Out:
#           video_id trending_date  \
# 34899  QBL8IRJ5yHU      18.15.05
# 34900  t4pRQ0jn23Q      18.15.05
# 34901  j4KvrAUjn6c      18.15.05
# 34902  MAjY8mCTXWk      18.15.05
# 34903  xhs8tf1v__w      18.15.05
# 34918  SNL|"Saturday Night Live"|"SNL Season 43"|"SNL...   1248343   15750
# 34919  $1000 Survival Kit|"Survival Kit in a Case"|"p...   1289899   51318
# 34921  NBC|"2018"|"New Show"|"trailer"|"promo"|"plane...   2061448    5290
# 34922  how to make a brilliant board|"bright board"|"...    454162    9815
# 34923  computer hacks|"cyber attack"|"computer virus"...    158406    6773
# 34924  mma|"ufc"|"amanda nunes"|"main event"|"raquel ...    769802    2777
# 34925  Kelly Clarkson|"Meaning of Life"|"mol"|"Offici...    494211   28080
# 34926  vat19|"vat19 nanodots"|"vat19 infinity gauntle...   2227658   29191
# 34927  ryan|"higa"|"higatv"|"nigahiga"|"fortnite"|"th...   8289563  408385
# 34928  timed mile in pe|"hannah"|"stocking"|"anwar"|"...   2271926   78125
# 34929  kids games|"family games"|"challenges"|"compet...   2058569   32574
# 34930  britain's got talent|"britains got talent"|"br...   1670008   25506
# 34931  this is america|"childish gambino"|"donald glo...   3513129  106481
# 34932  Buzzfeed|"eating your feed"|"viral food"|"cinn...   1207080   28615
# 34933                                             [none]   2652713   46420
# 34934  jaclynhill1|"jaclyn hill"|"makeup tutorial"|"s...   2288505   96852
# 34935  Jacksfilms|"Jack Douglass"|"YGS"|"YGS 100"|"YG...   1663506   79165
# 34936  wearing fashion nova outfits for a week|"fashi...   4106029  205285
# 34937  Rita Ora|"Rita"|"Ora"|"Your Song"|"Anywhere"|"...   4429079  189112
# 34938  abc|"network"|"tv"|"television"|"late"|"night"...   4867281   86356
# 34939  Dynamic robots|"Boston Dynamics"|"humanoid rob...   5650991   76461
# 34940  michelle khare|"buzzfeed michelle"|"organize"|...   1122213   28049
# 34941  Trailer|"Deadpool"|"20th Century Fox (Producti...  15960127  374825
# 34942  comedy|"entertainment"|"will smith"|"will"|"sm...   2055638  120377
# 34943  Clash Royale|"Clash Royale Game"|"Supercell"|"...  13418844  258720
# 34944  charlie puth|"boy"|"charlie"|"puth"|"atlantic"...   2124177   81085
# 34945  Jack and Dean|"OMFGItsJackAndDean"|"Jack Howar...    165617   20572
# 34946  Christina Aguilera|"Pop"|"RCA Records Label"|"...   1869585   64523
# 34947  espn|"espn live"|"dwane casey"|"raptors"|"toro...    472999    3505
# 34948  John|"Mayer"|"New"|"Light"|"Snack"|"Money"|"Po...   1201548   51670
#
#        dislikes  comment_count  comments_disabled  ratings_disabled  \
# 34899      3124          33032              False             False
# 34900      2380           7261              False             False
# 34901     12160          15874              False             False
# 34902      1042           4746              False             False
# 34903       132           1308              False             False
# 34904       307           1129              False             False
# 34905      6857           7796              False             False
# 34906       248            669              False             False
# 34907      1468           1870              False             False
# 34908      8028          13293              False             False
# 34909        79            642              False             False
# 34910      2345           6732              False             False
# 34911      2643           3698              False             False
# 34913      3290           3567              False             False
# 34914       337           1384              False             False
# 34915      1108           3323              False             False
# 34916       744           5017              False             False
# 34917       251           1087              False             False
# 34918      1919           1261              False             False
# 34919      1359           4332              False             False
# 34921      1861            546              False             False
# 34922       330           1489              False             False
# 34923       364            947              False             False
# 34924       667           1285              False             False
# 34925       426           1644              False             False
# 34926      1157           4092              False             False
# 34927     10966          21837              False             False
# 34928      4191           5868              False             False
# 34929      4195           5227              False             False
# 34930       740              0               True             False
# 34931      6922          18647              False             False
# 34932       598           1537              False             False
# 34933      4450           5561              False             False
# 34934      5530          12492              False             False
# 34935      1879          36476              False             False
# 34936      2180          11217              False             False
# 34937     22383          18998              False             False
# 34938     10524           3122              False             False
# 34939      2666          12187              False             False
# 34940      1299           1214              False             False
# 34941      3823           9059              False             False
# 34942       752           4872              False             False
# 34943     22805          19877              False             False
# 34944      1321           4019              False             False
# 34945       140           1407              False             False
# 34946      1891           5903              False             False
# 34947       163           1511              False             False
# 34948       964           4264              False             False
#
#        video_error_or_removed
# 34899                   False
# 34900                   False
# 34901                   False
# 34902                   False
# 34903                   False
# 34904                   False
# 34905                   False
# 34906                   False
# 34907                   False
# 34908                   False
# 34909                   False
# 34910                   False
# 34911                   False
# 34913                   False
# 34914                   False
# 34915                   False
# 34916                   False
# 34917                   False
# 34918                   False
# 34919                   False
# 34921                   False
# 34922                   False
# 34923                   False
# 34924                   False
# 34925                   False
# 34926                   False
# 34927                   False
# 34928                   False
# 34929                   False
# 34930                   False
# 34931                   False
# 34932                   False
# 34933                   False
# 34934                   False
# 34935                   False
# 34936                   False
# 34937                   False
# 34938                   False
# 34939                   False
# 34940                   False
# 34941                   False
# 34942                   False
# 34943                   False
# 34944                   False
# 34945                   False
# 34946                   False
# 34947                   False
# 34948                   False

# %%
df.drop_duplicates(inplace=True)

# %%
YouTube["trending_date"].apply(lambda x: '20' + x[:2]).value_counts(normalize = True)
# Out:
# 2018    0.765562
# 2017    0.234438
# Name: trending_date, dtype: float64

# %% [markdown]
# 76.6% of YouTube videos are from 2018 and only 23.4% of them are from 2017.

# %% [markdown]
# ### 4.3 Formatting columns : trending_date, publish_time, category_ID

# %% [markdown]
# Previously, we observed that trending_date and publish_time were object type. Here they will be converted into datetime objects. And afterwards new columns called 'published_date', and 'published_time' are being introduced for further analysis.

# %%
#Note that trending dates are in format year.date.month
df['trending_date'] = pd.to_datetime(df['trending_date'], format='%y.%d.%m')
df['publish_time'] = pd.to_datetime(df['publish_time'], format='%Y-%m-%dT%H:%M:%S.%fZ')

# %%
df['published_date'] = df['publish_time'].dt.date
df['published_time'] = df['publish_time'].dt.time

# %%
df1 = df.drop(columns='publish_time')
df1.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'comments_disabled', 'ratings_disabled', 'video_error_or_removed',
#        'published_date', 'published_time'],
#       dtype='object')

# %%
df1['trending_month'] = df1['trending_date'].dt.month
df1['trending_day'] = df1['trending_date'].dt.day

# %% [markdown]
# We can incorporate US_category_id.json file to our dataset and obtain different categories in our dataset instead of catogory_Ids.

# %%
df1['category_id'] = df1['category_id'].apply(str)

# %%
df1_categories = pd.read_json('./YOUTUBE DATA/US_category_id.json')

# %%
id_to_category = {}
for category in df1_categories['items']:
    id_to_category[category['id']]=category['snippet']['title']

# %%
df1['category']=df1['category_id'].map(id_to_category)

# %%
df2=df1.drop(columns='category_id')

# %%
df2.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE    2017-11-14
# 1  1ZAPwfrtAFY    2017-11-14
# 2  5qpjK5DgCt4    2017-11-14
# 3  puqaWrEC7tY    2017-11-14
# 4  d380meD0W0M    2017-11-14
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#                                                 tags    views   likes  \
# 0                                    SHANtell martin   748374   57527
# 1  last week tonight trump presidency|"last week ...  2418783   97185
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...  3191434  146033
# 3  rhett and link|"gmm"|"good mythical morning"|"...   343168   10172
# 4  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...  2095731  132235
#
#    dislikes  comment_count  comments_disabled  ratings_disabled  \
# 0      2966          15954              False             False
# 1      6146          12703              False             False
# 2      5339           8181              False             False
# 3       666           2146              False             False
# 4      1989          17518              False             False
#
#    video_error_or_removed published_date published_time  trending_month  \
# 0                   False     2017-11-13       17:13:01              11
# 1                   False     2017-11-13       07:30:00              11
# 2                   False     2017-11-12       19:05:24              11
# 3                   False     2017-11-13       11:00:04              11
# 4                   False     2017-11-12       18:01:41              11
#
#    trending_day        category
# 0            14  People & Blogs
# 1            14   Entertainment
# 2            14          Comedy
# 3            14   Entertainment
# 4            14   Entertainment

# %% [markdown]
# # 5. Explore Data

# %% [markdown]
# views, likes, dislikes, and comment_count are numerical variables in this dataset. We can explore them with the category type and channel_title to get some insights on data.

# %%
vldc = df2[['channel_title', 'category', 'views', 'likes', 'dislikes', 'comment_count']]

# %%
vldc.head()
# Out:
#            channel_title        category    views   likes  dislikes  \
# 0           CaseyNeistat  People & Blogs   748374   57527      2966
# 1        LastWeekTonight   Entertainment  2418783   97185      6146
# 2           Rudy Mancuso          Comedy  3191434  146033      5339
# 3  Good Mythical Morning   Entertainment   343168   10172       666
# 4               nigahiga   Entertainment  2095731  132235      1989
#
#    comment_count
# 0          15954
# 1          12703
# 2           8181
# 3           2146
# 4          17518

# %%
plt.figure(figsize=(15,10))
sns.countplot(y='category', data=vldc, order=vldc['category'].value_counts().index)
plt.show()

# %% [markdown]
# Most trending videos are from 'Entertainment' category, its' number of videos are close to 10000. One fourth of videos in the data set falls into this category (Total number of videos is 40901). category Nonprofits & Activism has the lowest number of videos in this dataset.

# %%
vldc['channel_title'].value_counts()
# Out:
# ESPN                                      202
# The Tonight Show Starring Jimmy Fallon    197
# Netflix                                   193
# Vox                                       192
# TheEllenShow                              192
#                                          ...
# 494ta                                       1
# Science vs Cinema                           1
# Total Combat                                1
# Hot Dad                                     1
# Maggie Smith Kühn                           1
# Name: channel_title, Length: 2207, dtype: int64

# %% [markdown]
# ESPN channel is the one that had appeared most in this trending list while 'The tonight show Starring Jimmy Fallon' is the second most and 'Netflix' is the third most channel title.

# %%
y = vldc.groupby(['category']).sum()
y.sort_values(by='comment_count', ascending=False)
# Out:
#                              views       likes  dislikes  comment_count
# category
# Music                  40126286541  1416572741  51173364      125275820
# Entertainment          20561101882   529233220  42904603       73448375
# People & Blogs          4910004664   186350335  10178864       24759019
# Howto & Style           4071011870   162515891   5462302       23095757
# Comedy                  5111266590   216136310   7219986       22496604
# Film & Animation        7267792432   165604731   6071246       17877359
# Gaming                  2127799781    68779564   9161661       14720836
# Science & Technology    3473462753    82255009   4531899       11954553
# Sports                  4403213872    98614929   5132721       11189359
# News & Politics         1473090484    18137189   4179491        6037217
# Education               1180175828    49247957   1351642        5440753
# Nonprofits & Activism    168941392    14815646   3310381        4808797
# Pets & Animals           764651989    19370702    527379        2660705
# Travel & Events          343100609     4825685    340090         910127
# Autos & Vehicles         520690717     4245656    243010         784447
# Shows                     51501058     1082639     24508          95117

# %%
def groupdata(col1, col2, color, num):
    y = vldc.groupby([col1]).sum()
    y = y.sort_values(by=col2, ascending=False)
    values = list(y[col2])
    categories = y.index
    plt.figure(figsize=(14,14))
    plt.subplot(4,1,num)
    plt.barh(categories, values, color = color)
    plt.ylabel(str(col2))
    plt.xticks(rotation=45)
    plt.show()

# %%
groupdata('category', 'views', 'red', 1)
groupdata('category', 'likes', 'blue', 2)
groupdata('category', 'dislikes', 'green', 3)
groupdata('category', 'comment_count', 'purple', 4)

# %% [markdown]
# Music category has the highest number of likes, dislikes, views, and comment_count, while shows has the least of them all. Music and Entertainment seem to be always dominating the first and second places when it comes to the number of likes, dislikes, comment count, and views in the trending list.

# %%
def top5(col1, col2):
    y = df2.groupby([col1]).sum()
    y = y.sort_values(by=col2, ascending=False).head()
    return y

# %% [markdown]
# Table below shows the video titles of the videos which had highest number of views in the trending YouTube video dataset.

# %%
top5('title', 'views')
# Out:
#                                                          views     likes  \
# title
# Childish Gambino - This Is America (Official Vi...  3758488765  96700818
# Ariana Grande - No Tears Left To Cry                1529291326  49451353
# BTS (방탄소년단) 'FAKE LOVE' Official MV                 1283188291  71835050
# Becky G, Natti Natasha - Sin Pijama (Official V...  1182971286  19185287
# VENOM - Official Trailer (HD)                       1003151226  23339807
#
#                                                     dislikes  comment_count  \
# title
# Childish Gambino - This Is America (Official Vi...   6054434       10151289
# Ariana Grande - No Tears Left To Cry                 1877988        4143608
# BTS (방탄소년단) 'FAKE LOVE' Official MV                  2389776       15568561
# Becky G, Natti Natasha - Sin Pijama (Official V...   1616616        1176862
# VENOM - Official Trailer (HD)                         831784        2533352
#
#                                                     comments_disabled  \
# title
# Childish Gambino - This Is America (Official Vi...                  0
# Ariana Grande - No Tears Left To Cry                                0
# BTS (방탄소년단) 'FAKE LOVE' Official MV                                 0
# Becky G, Natti Natasha - Sin Pijama (Official V...                  0
# VENOM - Official Trailer (HD)                                       0
#
#                                                     ratings_disabled  \
# title
# Childish Gambino - This Is America (Official Vi...                 0
# Ariana Grande - No Tears Left To Cry                               0
# BTS (방탄소년단) 'FAKE LOVE' Official MV                                0
# Becky G, Natti Natasha - Sin Pijama (Official V...                 0
# VENOM - Official Trailer (HD)                                      0
#
#                                                     video_error_or_removed  \
# title
# Childish Gambino - This Is America (Official Vi...                       0
# Ariana Grande - No Tears Left To Cry                                     0
# BTS (방탄소년단) 'FAKE LOVE' Official MV                                      0
# Becky G, Natti Natasha - Sin Pijama (Official V...                       0
# VENOM - Official Trailer (HD)                                            0
#
#                                                     trending_month  \
# title
# Childish Gambino - This Is America (Official Vi...             127
# Ariana Grande - No Tears Left To Cry                            90
# BTS (방탄소년단) 'FAKE LOVE' Official MV                             71
# Becky G, Natti Natasha - Sin Pijama (Official V...              90
# VENOM - Official Trailer (HD)                                   89
#
#                                                     trending_day
# title
# Childish Gambino - This Is America (Official Vi...           457
# Ariana Grande - No Tears Left To Cry                         314
# BTS (방탄소년단) 'FAKE LOVE' Official MV                          326
# Becky G, Natti Natasha - Sin Pijama (Official V...           315
# VENOM - Official Trailer (HD)                                257

# %% [markdown]
# Table below shows the video titles of the videos which had highest number of likes in the trending YouTube video dataset.

# %%
top5('title', 'likes')
# Out:
#                                                          views     likes  \
# title
# YouTube Rewind: The Shape of 2017 | #YouTubeRewind                       0
# So Sorry.                                                                0
# Childish Gambino - This Is America (Official Vi...                       0
# Official Call of Duty®: Black Ops 4 — Multiplay...                       0
# Suicide: Be Here Tomorrow.                                               0
#
#                                                     trending_month  \
# title
# YouTube Rewind: The Shape of 2017 | #YouTubeRewind              96
# So Sorry.                                                        7
# Childish Gambino - This Is America (Official Vi...             127
# Official Call of Duty®: Black Ops 4 — Multiplay...             144
# Suicide: Be Here Tomorrow.                                       9
#
#                                                     trending_day
# title
# YouTube Rewind: The Shape of 2017 | #YouTubeRewind            84
# So Sorry.                                                     42
# Childish Gambino - This Is America (Official Vi...           457
# Official Call of Duty®: Black Ops 4 — Multiplay...           411
# Suicide: Be Here Tomorrow.                                   197

# %%
corr_matrix = df2[['views', 'likes', 'dislikes', 'comment_count']].corr()
corr_matrix
# Out:
#                   views     likes  dislikes  comment_count
# views          1.000000  0.849179  0.472216       0.617657
# likes          0.849179  1.000000  0.447188       0.803088
# dislikes       0.472216  0.447188  1.000000       0.700192
# comment_count  0.617657  0.803088  0.700192       1.000000

# %% [markdown]
# Number of views and the number of likes seem to be positily correlated. Also, the number of comments and views seem to considerably correlated.

# %%
plt.figure(figsize=(10,8))
ax = sns.heatmap(corr_matrix, annot=True)

# %% [markdown]
# Likes and views have a strong correlation. comment_count and dislikes also have decent correlation with correlation coefficient of 0.7.

# %%
plt.figure(figsize = (15,8))
ax1 = sns.boxplot(x = df2['category'], y = np.log(df2['views']), data = df2)
ax1.set_title('views across catgegories')
plt.xticks(rotation = 45)
plt.show()

# %%
plt.figure(figsize = (15,8))
ax2 = sns.boxplot(x = df2['category'], y = np.log(df2['likes']), data = df2)
ax2.set_title('likes across catgegories')
plt.xticks(rotation = 45)
plt.show()
# Out:
# C:\Users\ROSA\anaconda3\lib\site-packages\pandas\core\series.py:726: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
plt.figure(figsize=(20,20))
stopwords = set(STOPWORDS)

wordcloud = WordCloud(background_color = 'darkgreen', stopwords=stopwords, 
                      max_words=100, max_font_size =120, random_state=42).generate(str(df2['title']))
plt.imshow(wordcloud)
plt.title('WORD CLOUD for Title')
plt.axis('off')
plt.show()

# %% [markdown]
# Above plotshows the most appeared words in the title of trending videos.

# %%
plt.figure(figsize = (12,8))
sns.lineplot(x = df2['trending_month'], y = df2['views'], data =df2, marker = 'o')
plt.show()

# %% [markdown]
# In the month of June, there had been the most number of views for the videos in the trending list.

# %%
plt.figure(figsize = (12,6))
sns.lineplot(x = df2['trending_day'], y = df2['views'], data =df2, marker = 'o')
plt.show()

# %% [markdown]
# Number of views has increased at the 10th day of a month, then have decreased until the 15th day of a month, and have been increasing towards the end of month

# %%
df2['likes/views'] = df2['likes']/df2['views']
df2['dislikes/views'] = df2['dislikes']/df2['views']
df2['comment_count/views'] = df2['comment_count']/df2['views']

# %%
df2[['likes/views', 'dislikes/views', 'comment_count/views']].head()
# Out:
#    likes/views  dislikes/views  comment_count/views
# 0     0.076869        0.003963             0.021318
# 1     0.040179        0.002541             0.005252
# 2     0.045758        0.001673             0.002563
# 3     0.029641        0.001941             0.006253
# 4     0.063097        0.000949             0.008359
